# %%
# importation de l'image
from skimage import io
simba = io.imread("simba.jpg")
print(simba.shape)
# Out:
# (574, 1020, 3)

# %%
# affichage de l'image
color_img = io.imshow(simba)

# %%
simba_noir = io.imread("simba.jpg", as_gray=True)
print(simba_noir.shape)
img_noir = io.imshow(simba_noir)
# Out:
# (574, 1020)

# %%
# hist
import matplotlib.pyplot as plt
n, bins, patches = plt.hist(simba.flatten(), bins = range(256))
plt.show()
